# %%
import pyforestplot as pfp

# %%
df = pfp.load_data('mortality')
df
# Out:
#                                    var                                  group  \
# 0              medicare $ per enrollee                  Access to health care
# 1    % change in population, 1980-2000          Local labor market conditions
# 2                   population density                          Other factors
# 3                       % black adults  Income inequality and social cohesion
# 4                          % uninsured                  Access to health care
# 5                   income segregation                  Environmental factors
# 6            unemployment rate in 2000          Local labor market conditions
# 7                  % college graduates                          Other factors
# 8                         % immigrants                          Other factors
# 9             index for social capital  Income inequality and social cohesion
# 10  % change in labor force, 1980-2000          Local labor market conditions
# ...
